# %% [markdown]
# ### Submitted By:
# # Indrashis Paul
# # 19MIM10046

# %% [markdown]
# # Importing required dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, GridSearchCV
from sklearn.linear_model import Perceptron

# %% [markdown]
# # Loading data

# %%
data = pd.read_csv('heart-categoric.csv')
print(data.shape)
data.head()
# Out:
# (23, 5)
#      age -    bp -    ch -    hr -   hd
# 0      Old     Low     Low  Medium   No
# 1  VeryOld     Low  Medium     Low  Yes
# 2      Old  Medium  Medium  Medium   No
# 3      Old     Low     Low     Low  Yes
# 4     Mild     Low     Low  Medium  Yes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age -   23 non-null     object
#  1   bp -    23 non-null     object
#  2   ch -    23 non-null     object
#  3   hr -    23 non-null     object
#  4   hd      23 non-null     object
# dtypes: object(5)
# memory usage: 1.0+ KB

# %% [markdown]
# # Preprocessing
# 1. Label Encoding the Target Column
# 2. Standard scaling the numerical data

# %%
le = LabelEncoder()

for col in data.columns:
    data[col] = le.fit_transform(data[col])
data.head()
# Out:
#    age -  bp -  ch -  hr -  hd
# 0      1     1     1     1   0
# 1      2     1     2     0   1
# 2      1     2     2     1   0
# 3      1     1     1     0   1
# 4      0     1     1     1   1

# %% [markdown]
# # Building the Perceptron for Classification

# %% [markdown]
# ## Split data

# %%
X = data.drop('hd', axis=1)
y = data['hd']

# %% [markdown]
# ## Using `sklearn.linear_model.Perceptron`

# %% [markdown]
# ### 1. Default Parameters

# %%
# define model
model = Perceptron()

# define model evaluation method
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# summarize result
print(scores)
print(f'Mean Accuracy: {np.mean(scores)} ({np.std(scores)})')
# Out:
# [0.66666667 0.66666667 0.66666667 0.5        1.         0.5
#  1.         1.         0.5        0.5        0.66666667 0.66666667
#  0.66666667 0.5        1.         0.5        1.         0.5
#  1.         0.5        1.         0.66666667 1.         0.
#  0.5        0.5        1.         0.5        0.5        1.        ]
# Mean Accuracy: 0.6888888888888888 (0.2499382639822665)

# %% [markdown]
# ### 2. Custom Parameters

# %%
model = Perceptron(penalty='l1', alpha=0.001, max_iter=2000, tol=1e-3, eta0=1.0021, class_weight='balanced', warm_start=True)

# define model evaluation method
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# summarize result
print(scores)
print(f'Mean Accuracy: {np.mean(scores)} ({np.std(scores)})')
# Out:
# [0.66666667 0.66666667 0.66666667 0.5        1.         0.5
#  1.         0.5        0.5        0.5        0.66666667 0.66666667
#  0.66666667 0.5        0.5        0.5        0.5        0.5
#  1.         0.5        1.         0.66666667 1.         0.
#  0.5        0.5        1.         0.5        0.5        1.        ]
# Mean Accuracy: 0.6388888888888888 (0.23207331749117138)

# %%
model = Perceptron(penalty='l2', alpha=0.00001, max_iter=1000, tol=None, eta0=1.005, class_weight='balanced', warm_start=False)

# define model evaluation method
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# summarize result
print(scores)
print(f'Mean Accuracy: {np.mean(scores)} ({np.std(scores)})')
# Out:
# [0.33333333 0.66666667 0.66666667 0.5        1.         0.5
#  1.         1.         0.5        1.         0.66666667 0.66666667
#  0.33333333 0.5        1.         0.5        1.         0.5
#  1.         1.         1.         1.         1.         0.
#  0.5        0.5        1.         0.5        1.         1.        ]
# Mean Accuracy: 0.7277777777777777 (0.28048679025254086)

# %% [markdown]
# ### 3. Hyperparameter Tuning

# %%
# define model
model = Perceptron()
# define model evaluation method
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# define grid
grid = dict()
grid['eta0'] = [0.0001, 0.001, 0.01, 0.1, 1.0]
grid['alpha'] = [0.0001, 0.001, 0.01, 0.1, 1.0]
grid['penalty'] = ['l1', 'l2', 'elasticnet', 'None']
grid['tol'] = [0.0001, 0.001, 0.01, 0.1, 1.0]

# define search
search = GridSearchCV(model, grid, scoring='accuracy', cv=cv, n_jobs=-1)
# perform the search
results = search.fit(X, y)
# summarize
print('Best Mean Accuracy: %.3f' % results.best_score_)
print('Best Config: %s' % results.best_params_)
# summarize all
means = results.cv_results_['mean_test_score']
params = results.cv_results_['params']
for mean, param in zip(means, params):
    print(">%.3f with: %r" % (mean, param))
# Out:
# Best Mean Accuracy: 0.689
# Best Config: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.0001}
# >0.617 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.0001}
# >0.633 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.001}
# >0.633 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.01}
# >0.633 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.1}
# >0.633 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 1.0}
# >0.572 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.0001}
# >0.611 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.001}
# >0.611 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.01}
# >0.611 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.1}
# >0.611 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 1.0}
# >0.589 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.600 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.600 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.600 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.600 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.661 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.0001}
# >0.628 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.001}
# >0.628 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.01}
# >0.628 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.1}
# >0.628 with: {'alpha': 0.0001, 'eta0': 0.0001, 'penalty': 'None', 'tol': 1.0}
# >0.656 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.0001}
# >0.572 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.001}
# >0.606 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.01}
# >0.606 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.1}
# >0.606 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'l1', 'tol': 1.0}
# >0.633 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.0001}
# >0.572 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.001}
# >0.611 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.01}
# >0.611 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.1}
# >0.611 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'l2', 'tol': 1.0}
# >0.611 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.589 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.600 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.600 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.600 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.689 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.0001}
# >0.583 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.001}
# >0.639 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.01}
# >0.639 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.1}
# >0.639 with: {'alpha': 0.0001, 'eta0': 0.001, 'penalty': 'None', 'tol': 1.0}
# >0.617 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.0001}
# >0.611 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.001}
# >0.606 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.01}
# >0.656 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.1}
# >0.656 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'l1', 'tol': 1.0}
# >0.650 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.0001}
# >0.633 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.001}
# >0.572 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.01}
# >0.611 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.1}
# >0.611 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'l2', 'tol': 1.0}
# >0.628 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.611 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.589 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.600 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.600 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.644 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.0001}
# >0.628 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.001}
# >0.650 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.01}
# >0.661 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.1}
# >0.661 with: {'alpha': 0.0001, 'eta0': 0.01, 'penalty': 'None', 'tol': 1.0}
# >0.639 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.0001}
# >0.639 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.001}
# >0.622 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.01}
# >0.589 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.1}
# >0.650 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'l1', 'tol': 1.0}
# >0.650 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.0001}
# >0.650 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.001}
# >0.633 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.01}
# >0.572 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.1}
# >0.611 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'l2', 'tol': 1.0}
# >0.644 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.644 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.628 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.589 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.633 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.661 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.0001}
# >0.661 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.001}
# >0.661 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.01}
# >0.594 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.1}
# >0.656 with: {'alpha': 0.0001, 'eta0': 0.1, 'penalty': 'None', 'tol': 1.0}
# >0.606 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.0001}
# >0.606 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.001}
# >0.606 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.01}
# >0.617 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.1}
# >0.583 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'l1', 'tol': 1.0}
# >0.650 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.0001}
# >0.650 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.001}
# >0.650 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.01}
# >0.650 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.1}
# >0.572 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'l2', 'tol': 1.0}
# >0.572 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.572 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.572 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.572 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.583 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.689 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.0001}
# >0.689 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.001}
# >0.689 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.01}
# >0.672 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.1}
# >0.633 with: {'alpha': 0.0001, 'eta0': 1.0, 'penalty': 'None', 'tol': 1.0}
# >0.606 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.0001}
# >0.650 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.001}
# >0.650 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.01}
# >0.650 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.1}
# >0.650 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 1.0}
# >0.572 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.0001}
# >0.611 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.001}
# >0.611 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.01}
# >0.611 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.1}
# >0.611 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 1.0}
# >0.589 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.600 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.600 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.600 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.600 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.661 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.0001}
# >0.628 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.001}
# >0.628 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.01}
# >0.628 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.1}
# >0.628 with: {'alpha': 0.001, 'eta0': 0.0001, 'penalty': 'None', 'tol': 1.0}
# >0.622 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.0001}
# >0.561 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.001}
# >0.639 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.01}
# >0.639 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.1}
# >0.639 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'l1', 'tol': 1.0}
# >0.633 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.0001}
# >0.572 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.001}
# >0.611 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.01}
# >0.611 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.1}
# >0.611 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'l2', 'tol': 1.0}
# >0.611 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.589 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.600 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.600 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.600 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.689 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.0001}
# >0.583 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.001}
# >0.639 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.01}
# >0.639 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.1}
# >0.639 with: {'alpha': 0.001, 'eta0': 0.001, 'penalty': 'None', 'tol': 1.0}
# >0.633 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.0001}
# >0.611 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.001}
# >0.628 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.01}
# >0.622 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.1}
# >0.622 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'l1', 'tol': 1.0}
# >0.650 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.0001}
# >0.633 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.001}
# >0.572 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.01}
# >0.611 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.1}
# >0.611 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'l2', 'tol': 1.0}
# >0.628 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.611 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.589 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.600 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.600 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.644 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.0001}
# >0.628 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.001}
# >0.650 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.01}
# >0.661 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.1}
# >0.661 with: {'alpha': 0.001, 'eta0': 0.01, 'penalty': 'None', 'tol': 1.0}
# >0.617 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.0001}
# >0.633 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.001}
# >0.617 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.01}
# >0.572 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.1}
# >0.606 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'l1', 'tol': 1.0}
# >0.650 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.0001}
# >0.650 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.001}
# >0.650 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.01}
# >0.572 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.1}
# >0.611 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'l2', 'tol': 1.0}
# >0.644 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.644 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.628 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.589 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.633 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.661 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.0001}
# >0.661 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.001}
# >0.661 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.01}
# >0.594 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.1}
# >0.656 with: {'alpha': 0.001, 'eta0': 0.1, 'penalty': 'None', 'tol': 1.0}
# >0.639 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.0001}
# >0.639 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.001}
# >0.639 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.01}
# >0.622 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.1}
# >0.606 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'l1', 'tol': 1.0}
# >0.606 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.0001}
# >0.606 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.001}
# >0.606 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.01}
# >0.589 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.1}
# >0.561 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'l2', 'tol': 1.0}
# >0.567 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.567 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.583 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.583 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.583 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.689 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.0001}
# >0.689 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.001}
# >0.689 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.01}
# >0.672 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.1}
# >0.633 with: {'alpha': 0.001, 'eta0': 1.0, 'penalty': 'None', 'tol': 1.0}
# >0.600 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.0001}
# >0.600 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.001}
# >0.600 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.01}
# >0.600 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.1}
# >0.600 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 1.0}
# >0.572 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.0001}
# >0.611 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.001}
# >0.611 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.01}
# >0.611 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.1}
# >0.611 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 1.0}
# >0.572 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.600 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.600 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.600 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.600 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.661 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.0001}
# >0.628 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.001}
# >0.628 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.01}
# >0.628 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.1}
# >0.628 with: {'alpha': 0.01, 'eta0': 0.0001, 'penalty': 'None', 'tol': 1.0}
# >0.600 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.0001}
# >0.583 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.001}
# >0.617 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.01}
# >0.617 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.1}
# >0.617 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'l1', 'tol': 1.0}
# >0.633 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.0001}
# >0.572 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.001}
# >0.611 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.01}
# >0.611 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.1}
# >0.611 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'l2', 'tol': 1.0}
# >0.628 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.572 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.600 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.600 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.600 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.689 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.0001}
# >0.583 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.001}
# >0.639 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.01}
# >0.639 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.1}
# >0.639 with: {'alpha': 0.01, 'eta0': 0.001, 'penalty': 'None', 'tol': 1.0}
# >0.650 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.0001}
# >0.650 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.001}
# >0.617 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.01}
# >0.617 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.1}
# >0.617 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'l1', 'tol': 1.0}
# >0.650 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.0001}
# >0.650 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.001}
# >0.572 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.01}
# >0.611 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.1}
# >0.611 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'l2', 'tol': 1.0}
# >0.644 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.628 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.572 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.600 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.600 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.644 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.0001}
# >0.628 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.001}
# >0.650 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.01}
# >0.661 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.1}
# >0.661 with: {'alpha': 0.01, 'eta0': 0.01, 'penalty': 'None', 'tol': 1.0}
# >0.650 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.0001}
# >0.650 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.001}
# >0.611 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.01}
# >0.594 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.1}
# >0.600 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'l1', 'tol': 1.0}
# >0.606 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.0001}
# >0.606 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.001}
# >0.589 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.01}
# >0.561 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.1}
# >0.611 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'l2', 'tol': 1.0}
# >0.650 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.650 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.594 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.589 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.633 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.661 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.0001}
# >0.661 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.001}
# >0.661 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.01}
# >0.594 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.1}
# >0.656 with: {'alpha': 0.01, 'eta0': 0.1, 'penalty': 'None', 'tol': 1.0}
# >0.611 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.0001}
# >0.611 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.001}
# >0.611 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.01}
# >0.600 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.1}
# >0.572 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'l1', 'tol': 1.0}
# >0.544 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.0001}
# >0.544 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.001}
# >0.544 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.01}
# >0.517 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.1}
# >0.533 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'l2', 'tol': 1.0}
# >0.583 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.583 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.583 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.589 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.550 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.689 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.0001}
# >0.689 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.001}
# >0.689 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.01}
# >0.672 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.1}
# >0.633 with: {'alpha': 0.01, 'eta0': 1.0, 'penalty': 'None', 'tol': 1.0}
# >0.572 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.0001}
# >0.567 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.001}
# >0.567 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.01}
# >0.567 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.1}
# >0.567 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 1.0}
# >0.572 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.0001}
# >0.611 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.001}
# >0.611 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.01}
# >0.611 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.1}
# >0.611 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 1.0}
# >0.589 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.628 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.628 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.628 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.628 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.661 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.0001}
# >0.628 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.001}
# >0.628 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.01}
# >0.628 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.1}
# >0.628 with: {'alpha': 0.1, 'eta0': 0.0001, 'penalty': 'None', 'tol': 1.0}
# >0.589 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.0001}
# >0.589 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.001}
# >0.633 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.01}
# >0.633 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.1}
# >0.633 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'l1', 'tol': 1.0}
# >0.650 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.0001}
# >0.572 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.001}
# >0.611 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.01}
# >0.611 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.1}
# >0.611 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'l2', 'tol': 1.0}
# >0.633 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.606 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.644 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.644 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.644 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.689 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.0001}
# >0.583 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.001}
# >0.639 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.01}
# >0.639 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.1}
# >0.639 with: {'alpha': 0.1, 'eta0': 0.001, 'penalty': 'None', 'tol': 1.0}
# >0.478 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.0001}
# >0.528 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.001}
# >0.544 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.01}
# >0.572 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.1}
# >0.572 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'l1', 'tol': 1.0}
# >0.606 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.0001}
# >0.589 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.001}
# >0.561 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.01}
# >0.611 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.1}
# >0.611 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'l2', 'tol': 1.0}
# >0.572 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.589 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.572 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.622 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.622 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.644 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.0001}
# >0.628 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.001}
# >0.650 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.01}
# >0.661 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.1}
# >0.661 with: {'alpha': 0.1, 'eta0': 0.01, 'penalty': 'None', 'tol': 1.0}
# >0.589 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.0001}
# >0.589 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.001}
# >0.572 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.01}
# >0.567 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.1}
# >0.567 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'l1', 'tol': 1.0}
# >0.544 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.0001}
# >0.544 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.001}
# >0.517 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.01}
# >0.533 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.1}
# >0.628 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'l2', 'tol': 1.0}
# >0.633 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.633 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.622 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.589 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.578 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.661 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.0001}
# >0.661 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.001}
# >0.661 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.01}
# >0.594 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.1}
# >0.656 with: {'alpha': 0.1, 'eta0': 0.1, 'penalty': 'None', 'tol': 1.0}
# >0.506 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.0001}
# >0.506 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.001}
# >0.522 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.01}
# >0.533 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.1}
# >0.561 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'l1', 'tol': 1.0}
# >0.433 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.0001}
# >0.433 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.001}
# >0.433 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.01}
# >0.467 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.1}
# >0.544 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'l2', 'tol': 1.0}
# >0.561 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.561 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.561 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.578 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.589 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.689 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.0001}
# >0.689 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.001}
# >0.689 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.01}
# >0.672 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.1}
# >0.633 with: {'alpha': 0.1, 'eta0': 1.0, 'penalty': 'None', 'tol': 1.0}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.0001}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.001}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.01}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 0.1}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'l1', 'tol': 1.0}
# >0.572 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.0001}
# >0.611 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.001}
# >0.611 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.01}
# >0.611 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 0.1}
# >0.611 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'l2', 'tol': 1.0}
# >0.478 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.661 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.0001}
# >0.628 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.001}
# >0.628 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.01}
# >0.628 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'None', 'tol': 0.1}
# >0.628 with: {'alpha': 1.0, 'eta0': 0.0001, 'penalty': 'None', 'tol': 1.0}
# >0.506 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.0001}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.001}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.01}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'l1', 'tol': 0.1}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'l1', 'tol': 1.0}
# >0.589 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.0001}
# >0.561 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.001}
# >0.611 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.01}
# >0.611 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'l2', 'tol': 0.1}
# >0.611 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'l2', 'tol': 1.0}
# >0.528 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.461 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.500 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.500 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.500 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.689 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.0001}
# >0.583 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.001}
# >0.639 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.01}
# >0.639 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'None', 'tol': 0.1}
# >0.639 with: {'alpha': 1.0, 'eta0': 0.001, 'penalty': 'None', 'tol': 1.0}
# >0.483 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.0001}
# >0.506 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.001}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.01}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'l1', 'tol': 0.1}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'l1', 'tol': 1.0}
# >0.544 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.0001}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.001}
# >0.533 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.01}
# >0.628 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'l2', 'tol': 0.1}
# >0.628 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'l2', 'tol': 1.0}
# >0.500 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.522 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.494 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.644 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.0001}
# >0.628 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.001}
# >0.650 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.01}
# >0.661 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'None', 'tol': 0.1}
# >0.661 with: {'alpha': 1.0, 'eta0': 0.01, 'penalty': 'None', 'tol': 1.0}
# >0.483 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.0001}
# >0.483 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.001}
# >0.506 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.01}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'l1', 'tol': 0.1}
# >0.517 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'l1', 'tol': 1.0}
# >0.433 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.0001}
# >0.433 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.001}
# >0.467 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.01}
# >0.544 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'l2', 'tol': 0.1}
# >0.556 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'l2', 'tol': 1.0}
# >0.483 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.472 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.494 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.489 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.467 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.661 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.0001}
# >0.661 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.001}
# >0.661 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.01}
# >0.594 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'None', 'tol': 0.1}
# >0.656 with: {'alpha': 1.0, 'eta0': 0.1, 'penalty': 'None', 'tol': 1.0}
# >0.483 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.0001}
# >0.483 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.001}
# >0.483 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.01}
# >0.506 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'l1', 'tol': 0.1}
# >0.517 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'l1', 'tol': 1.0}
# >0.472 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.0001}
# >0.472 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.001}
# >0.472 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.01}
# >0.472 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'l2', 'tol': 0.1}
# >0.472 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'l2', 'tol': 1.0}
# >0.494 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.0001}
# >0.494 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.001}
# >0.494 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.01}
# >0.483 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 0.1}
# >0.506 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'elasticnet', 'tol': 1.0}
# >0.689 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.0001}
# >0.689 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.001}
# >0.689 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.01}
# >0.672 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'None', 'tol': 0.1}
# >0.633 with: {'alpha': 1.0, 'eta0': 1.0, 'penalty': 'None', 'tol': 1.0}

# %% [markdown]
# ## Using `tf.keras.layers.Dense`

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, MinMaxScaler
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %%
model = Sequential()
model.add(Dense(16, input_shape=(4,), activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 16)                80
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 97
# Trainable params: 97
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X, y, batch_size=10, epochs=200, verbose=2, validation_split=0.2)
# Out:
# Epoch 1/200
# 2/2 - 0s - loss: 0.6018 - accuracy: 0.8333 - val_loss: 0.6490 - val_accuracy: 0.8000
# Epoch 2/200
# 2/2 - 0s - loss: 0.6000 - accuracy: 0.8333 - val_loss: 0.6485 - val_accuracy: 0.8000
# Epoch 3/200
# 2/2 - 0s - loss: 0.5964 - accuracy: 0.8333 - val_loss: 0.6456 - val_accuracy: 0.8000
# Epoch 4/200
# 2/2 - 0s - loss: 0.5939 - accuracy: 0.8333 - val_loss: 0.6431 - val_accuracy: 0.8000
# Epoch 5/200
# 2/2 - 0s - loss: 0.5921 - accuracy: 0.8333 - val_loss: 0.6406 - val_accuracy: 0.8000
# Epoch 6/200
# 2/2 - 0s - loss: 0.5899 - accuracy: 0.8333 - val_loss: 0.6386 - val_accuracy: 0.8000
# Epoch 7/200
# 2/2 - 0s - loss: 0.5889 - accuracy: 0.8333 - val_loss: 0.6357 - val_accuracy: 0.8000
# Epoch 8/200
# 2/2 - 0s - loss: 0.5868 - accuracy: 0.8333 - val_loss: 0.6332 - val_accuracy: 0.8000
# Epoch 9/200
# 2/2 - 0s - loss: 0.5856 - accuracy: 0.8333 - val_loss: 0.6311 - val_accuracy: 0.8000
# Epoch 10/200
# 2/2 - 0s - loss: 0.5833 - accuracy: 0.8333 - val_loss: 0.6304 - val_accuracy: 0.8000
# Epoch 11/200
# 2/2 - 0s - loss: 0.5819 - accuracy: 0.8333 - val_loss: 0.6294 - val_accuracy: 0.8000
# Epoch 12/200
# 2/2 - 0s - loss: 0.5801 - accuracy: 0.8333 - val_loss: 0.6295 - val_accuracy: 0.8000
# Epoch 13/200
# 2/2 - 0s - loss: 0.5786 - accuracy: 0.8333 - val_loss: 0.6293 - val_accuracy: 0.8000
# Epoch 14/200
# 2/2 - 0s - loss: 0.5768 - accuracy: 0.8333 - val_loss: 0.6286 - val_accuracy: 0.8000
# Epoch 15/200
# 2/2 - 0s - loss: 0.5758 - accuracy: 0.8333 - val_loss: 0.6280 - val_accuracy: 0.8000
# Epoch 16/200
# 2/2 - 0s - loss: 0.5743 - accuracy: 0.8333 - val_loss: 0.6272 - val_accuracy: 0.8000
# Epoch 17/200
# 2/2 - 0s - loss: 0.5728 - accuracy: 0.8333 - val_loss: 0.6256 - val_accuracy: 0.8000
# Epoch 18/200
# 2/2 - 0s - loss: 0.5716 - accuracy: 0.8333 - val_loss: 0.6242 - val_accuracy: 0.8000
# Epoch 19/200
# 2/2 - 0s - loss: 0.5698 - accuracy: 0.8333 - val_loss: 0.6233 - val_accuracy: 0.8000
# Epoch 20/200
# 2/2 - 0s - loss: 0.5685 - accuracy: 0.8333 - val_loss: 0.6233 - val_accuracy: 0.8000
# Epoch 21/200
# 2/2 - 0s - loss: 0.5673 - accuracy: 0.8333 - val_loss: 0.6223 - val_accuracy: 0.8000
# Epoch 22/200
# 2/2 - 0s - loss: 0.5662 - accuracy: 0.8333 - val_loss: 0.6216 - val_accuracy: 0.8000
# Epoch 23/200
# 2/2 - 0s - loss: 0.5646 - accuracy: 0.8333 - val_loss: 0.6211 - val_accuracy: 0.8000
# Epoch 24/200
# 2/2 - 0s - loss: 0.5633 - accuracy: 0.8333 - val_loss: 0.6206 - val_accuracy: 0.8000
# Epoch 25/200
# 2/2 - 0s - loss: 0.5618 - accuracy: 0.8333 - val_loss: 0.6203 - val_accuracy: 0.8000
# Epoch 26/200
# 2/2 - 0s - loss: 0.5607 - accuracy: 0.8333 - val_loss: 0.6197 - val_accuracy: 0.8000
# Epoch 27/200
# 2/2 - 0s - loss: 0.5596 - accuracy: 0.8333 - val_loss: 0.6187 - val_accuracy: 0.8000
# Epoch 28/200
# 2/2 - 0s - loss: 0.5583 - accuracy: 0.8333 - val_loss: 0.6187 - val_accuracy: 0.8000
# Epoch 29/200
# 2/2 - 0s - loss: 0.5570 - accuracy: 0.8333 - val_loss: 0.6179 - val_accuracy: 0.8000
# Epoch 30/200
# 2/2 - 0s - loss: 0.5558 - accuracy: 0.8333 - val_loss: 0.6167 - val_accuracy: 0.8000
# Epoch 31/200
# 2/2 - 0s - loss: 0.5544 - accuracy: 0.8333 - val_loss: 0.6156 - val_accuracy: 0.8000
# Epoch 32/200
# 2/2 - 0s - loss: 0.5534 - accuracy: 0.8333 - val_loss: 0.6145 - val_accuracy: 0.8000
# Epoch 33/200
# 2/2 - 0s - loss: 0.5523 - accuracy: 0.8333 - val_loss: 0.6133 - val_accuracy: 0.8000
# Epoch 34/200
# 2/2 - 0s - loss: 0.5513 - accuracy: 0.8333 - val_loss: 0.6127 - val_accuracy: 0.8000
# Epoch 35/200
# 2/2 - 0s - loss: 0.5499 - accuracy: 0.8333 - val_loss: 0.6123 - val_accuracy: 0.8000
# Epoch 36/200
# 2/2 - 0s - loss: 0.5491 - accuracy: 0.8333 - val_loss: 0.6109 - val_accuracy: 0.8000
# Epoch 37/200
# 2/2 - 0s - loss: 0.5477 - accuracy: 0.8333 - val_loss: 0.6103 - val_accuracy: 0.8000
# Epoch 38/200
# 2/2 - 0s - loss: 0.5468 - accuracy: 0.8889 - val_loss: 0.6095 - val_accuracy: 0.8000
# Epoch 39/200
# 2/2 - 0s - loss: 0.5457 - accuracy: 0.8889 - val_loss: 0.6083 - val_accuracy: 0.8000
# Epoch 40/200
# 2/2 - 0s - loss: 0.5448 - accuracy: 0.8889 - val_loss: 0.6066 - val_accuracy: 0.8000
# Epoch 41/200
# 2/2 - 0s - loss: 0.5433 - accuracy: 0.8889 - val_loss: 0.6048 - val_accuracy: 0.8000
# Epoch 42/200
# 2/2 - 0s - loss: 0.5424 - accuracy: 0.8889 - val_loss: 0.6033 - val_accuracy: 0.8000
# Epoch 43/200
# 2/2 - 0s - loss: 0.5414 - accuracy: 0.8889 - val_loss: 0.6013 - val_accuracy: 0.8000
# Epoch 44/200
# 2/2 - 0s - loss: 0.5406 - accuracy: 0.8889 - val_loss: 0.5994 - val_accuracy: 0.8000
# Epoch 45/200
# 2/2 - 0s - loss: 0.5394 - accuracy: 0.8889 - val_loss: 0.5979 - val_accuracy: 0.8000
# Epoch 46/200
# 2/2 - 0s - loss: 0.5384 - accuracy: 0.8333 - val_loss: 0.5968 - val_accuracy: 0.8000
# Epoch 47/200
# 2/2 - 0s - loss: 0.5374 - accuracy: 0.8333 - val_loss: 0.5956 - val_accuracy: 0.8000
# Epoch 48/200
# 2/2 - 0s - loss: 0.5368 - accuracy: 0.8333 - val_loss: 0.5946 - val_accuracy: 0.8000
# Epoch 49/200
# 2/2 - 0s - loss: 0.5357 - accuracy: 0.8333 - val_loss: 0.5931 - val_accuracy: 0.8000
# Epoch 50/200
# 2/2 - 0s - loss: 0.5347 - accuracy: 0.8333 - val_loss: 0.5926 - val_accuracy: 0.8000
# Epoch 51/200
# 2/2 - 0s - loss: 0.5337 - accuracy: 0.8333 - val_loss: 0.5922 - val_accuracy: 0.8000
# Epoch 52/200
# 2/2 - 0s - loss: 0.5325 - accuracy: 0.8333 - val_loss: 0.5916 - val_accuracy: 0.8000
# Epoch 53/200
# 2/2 - 0s - loss: 0.5320 - accuracy: 0.8333 - val_loss: 0.5915 - val_accuracy: 0.8000
# Epoch 54/200
# 2/2 - 0s - loss: 0.5315 - accuracy: 0.8333 - val_loss: 0.5901 - val_accuracy: 0.8000
# Epoch 55/200
# 2/2 - 0s - loss: 0.5299 - accuracy: 0.8333 - val_loss: 0.5901 - val_accuracy: 0.8000
# Epoch 56/200
# 2/2 - 0s - loss: 0.5290 - accuracy: 0.8333 - val_loss: 0.5898 - val_accuracy: 0.8000
# Epoch 57/200
# 2/2 - 0s - loss: 0.5284 - accuracy: 0.8333 - val_loss: 0.5902 - val_accuracy: 0.8000
# Epoch 58/200
# 2/2 - 0s - loss: 0.5274 - accuracy: 0.8333 - val_loss: 0.5902 - val_accuracy: 0.8000
# Epoch 59/200
# 2/2 - 0s - loss: 0.5264 - accuracy: 0.8333 - val_loss: 0.5892 - val_accuracy: 0.8000
# Epoch 60/200
# 2/2 - 0s - loss: 0.5256 - accuracy: 0.8333 - val_loss: 0.5889 - val_accuracy: 0.8000
# Epoch 61/200
# 2/2 - 0s - loss: 0.5245 - accuracy: 0.8333 - val_loss: 0.5877 - val_accuracy: 0.8000
# Epoch 62/200
# 2/2 - 0s - loss: 0.5234 - accuracy: 0.8333 - val_loss: 0.5873 - val_accuracy: 0.8000
# Epoch 63/200
# 2/2 - 0s - loss: 0.5225 - accuracy: 0.8333 - val_loss: 0.5871 - val_accuracy: 0.8000
# Epoch 64/200
# 2/2 - 0s - loss: 0.5219 - accuracy: 0.8333 - val_loss: 0.5868 - val_accuracy: 0.8000
# Epoch 65/200
# 2/2 - 0s - loss: 0.5207 - accuracy: 0.8333 - val_loss: 0.5860 - val_accuracy: 0.8000
# Epoch 66/200
# 2/2 - 0s - loss: 0.5202 - accuracy: 0.8333 - val_loss: 0.5858 - val_accuracy: 0.8000
# Epoch 67/200
# 2/2 - 0s - loss: 0.5194 - accuracy: 0.8333 - val_loss: 0.5845 - val_accuracy: 0.8000
# Epoch 68/200
# 2/2 - 0s - loss: 0.5185 - accuracy: 0.8333 - val_loss: 0.5837 - val_accuracy: 0.8000
# Epoch 69/200
# 2/2 - 0s - loss: 0.5176 - accuracy: 0.8333 - val_loss: 0.5841 - val_accuracy: 0.8000
# Epoch 70/200
# 2/2 - 0s - loss: 0.5166 - accuracy: 0.8333 - val_loss: 0.5839 - val_accuracy: 0.8000
# Epoch 71/200
# 2/2 - 0s - loss: 0.5156 - accuracy: 0.8333 - val_loss: 0.5835 - val_accuracy: 0.8000
# Epoch 72/200
# 2/2 - 0s - loss: 0.5149 - accuracy: 0.8333 - val_loss: 0.5831 - val_accuracy: 0.8000
# Epoch 73/200
# 2/2 - 0s - loss: 0.5141 - accuracy: 0.8333 - val_loss: 0.5827 - val_accuracy: 0.8000
# Epoch 74/200
# 2/2 - 0s - loss: 0.5137 - accuracy: 0.8333 - val_loss: 0.5821 - val_accuracy: 0.8000
# Epoch 75/200
# 2/2 - 0s - loss: 0.5126 - accuracy: 0.8333 - val_loss: 0.5820 - val_accuracy: 0.8000
# Epoch 76/200
# 2/2 - 0s - loss: 0.5127 - accuracy: 0.8333 - val_loss: 0.5830 - val_accuracy: 0.8000
# Epoch 77/200
# 2/2 - 0s - loss: 0.5110 - accuracy: 0.8333 - val_loss: 0.5830 - val_accuracy: 0.8000
# Epoch 78/200
# 2/2 - 0s - loss: 0.5102 - accuracy: 0.8333 - val_loss: 0.5825 - val_accuracy: 0.8000
# Epoch 79/200
# 2/2 - 0s - loss: 0.5095 - accuracy: 0.8333 - val_loss: 0.5821 - val_accuracy: 0.8000
# Epoch 80/200
# 2/2 - 0s - loss: 0.5087 - accuracy: 0.8333 - val_loss: 0.5820 - val_accuracy: 0.8000
# Epoch 81/200
# 2/2 - 0s - loss: 0.5080 - accuracy: 0.8333 - val_loss: 0.5817 - val_accuracy: 0.8000
# Epoch 82/200
# 2/2 - 0s - loss: 0.5073 - accuracy: 0.8333 - val_loss: 0.5815 - val_accuracy: 0.8000
# Epoch 83/200
# 2/2 - 0s - loss: 0.5064 - accuracy: 0.8333 - val_loss: 0.5817 - val_accuracy: 0.8000
# Epoch 84/200
# 2/2 - 0s - loss: 0.5057 - accuracy: 0.8333 - val_loss: 0.5817 - val_accuracy: 0.8000
# Epoch 85/200
# 2/2 - 0s - loss: 0.5052 - accuracy: 0.8333 - val_loss: 0.5818 - val_accuracy: 0.8000
# Epoch 86/200
# 2/2 - 0s - loss: 0.5042 - accuracy: 0.8333 - val_loss: 0.5822 - val_accuracy: 0.8000
# Epoch 87/200
# 2/2 - 0s - loss: 0.5037 - accuracy: 0.8889 - val_loss: 0.5824 - val_accuracy: 0.8000
# Epoch 88/200
# 2/2 - 0s - loss: 0.5032 - accuracy: 0.8889 - val_loss: 0.5827 - val_accuracy: 0.8000
# Epoch 89/200
# 2/2 - 0s - loss: 0.5027 - accuracy: 0.8889 - val_loss: 0.5819 - val_accuracy: 0.8000
# Epoch 90/200
# 2/2 - 0s - loss: 0.5017 - accuracy: 0.8889 - val_loss: 0.5821 - val_accuracy: 0.8000
# Epoch 91/200
# 2/2 - 0s - loss: 0.5007 - accuracy: 0.8889 - val_loss: 0.5817 - val_accuracy: 0.8000
# Epoch 92/200
# 2/2 - 0s - loss: 0.5001 - accuracy: 0.8889 - val_loss: 0.5815 - val_accuracy: 0.8000
# Epoch 93/200
# 2/2 - 0s - loss: 0.4995 - accuracy: 0.8889 - val_loss: 0.5810 - val_accuracy: 0.8000
# Epoch 94/200
# 2/2 - 0s - loss: 0.4992 - accuracy: 0.8333 - val_loss: 0.5798 - val_accuracy: 0.8000
# Epoch 95/200
# 2/2 - 0s - loss: 0.4981 - accuracy: 0.8333 - val_loss: 0.5794 - val_accuracy: 0.8000
# Epoch 96/200
# 2/2 - 0s - loss: 0.4974 - accuracy: 0.8333 - val_loss: 0.5791 - val_accuracy: 0.8000
# Epoch 97/200
# 2/2 - 0s - loss: 0.4971 - accuracy: 0.8333 - val_loss: 0.5794 - val_accuracy: 0.8000
# Epoch 98/200
# 2/2 - 0s - loss: 0.4966 - accuracy: 0.8333 - val_loss: 0.5784 - val_accuracy: 0.8000
# Epoch 99/200
# 2/2 - 0s - loss: 0.4954 - accuracy: 0.8333 - val_loss: 0.5783 - val_accuracy: 0.8000
# Epoch 100/200
# 2/2 - 0s - loss: 0.4949 - accuracy: 0.8333 - val_loss: 0.5783 - val_accuracy: 0.8000
# Epoch 101/200
# 2/2 - 0s - loss: 0.4943 - accuracy: 0.8333 - val_loss: 0.5777 - val_accuracy: 0.8000
# Epoch 102/200
# 2/2 - 0s - loss: 0.4937 - accuracy: 0.8333 - val_loss: 0.5778 - val_accuracy: 0.8000
# Epoch 103/200
# 2/2 - 0s - loss: 0.4931 - accuracy: 0.8333 - val_loss: 0.5773 - val_accuracy: 0.8000
# Epoch 104/200
# 2/2 - 0s - loss: 0.4924 - accuracy: 0.8333 - val_loss: 0.5769 - val_accuracy: 0.8000
# Epoch 105/200
# 2/2 - 0s - loss: 0.4919 - accuracy: 0.8333 - val_loss: 0.5765 - val_accuracy: 0.8000
# Epoch 106/200
# 2/2 - 0s - loss: 0.4912 - accuracy: 0.8333 - val_loss: 0.5765 - val_accuracy: 0.8000
# Epoch 107/200
# 2/2 - 0s - loss: 0.4906 - accuracy: 0.8333 - val_loss: 0.5764 - val_accuracy: 0.8000
# Epoch 108/200
# 2/2 - 0s - loss: 0.4898 - accuracy: 0.8333 - val_loss: 0.5762 - val_accuracy: 0.8000
# Epoch 109/200
# 2/2 - 0s - loss: 0.4895 - accuracy: 0.8333 - val_loss: 0.5763 - val_accuracy: 0.8000
# Epoch 110/200
# 2/2 - 0s - loss: 0.4887 - accuracy: 0.8333 - val_loss: 0.5759 - val_accuracy: 0.8000
# Epoch 111/200
# 2/2 - 0s - loss: 0.4885 - accuracy: 0.8333 - val_loss: 0.5761 - val_accuracy: 0.8000
# Epoch 112/200
# 2/2 - 0s - loss: 0.4876 - accuracy: 0.8333 - val_loss: 0.5758 - val_accuracy: 0.8000
# Epoch 113/200
# 2/2 - 0s - loss: 0.4871 - accuracy: 0.8333 - val_loss: 0.5750 - val_accuracy: 0.8000
# Epoch 114/200
# 2/2 - 0s - loss: 0.4866 - accuracy: 0.8333 - val_loss: 0.5743 - val_accuracy: 0.8000
# Epoch 115/200
# 2/2 - 0s - loss: 0.4860 - accuracy: 0.8333 - val_loss: 0.5736 - val_accuracy: 0.8000
# Epoch 116/200
# 2/2 - 0s - loss: 0.4854 - accuracy: 0.8333 - val_loss: 0.5738 - val_accuracy: 0.8000
# Epoch 117/200
# 2/2 - 0s - loss: 0.4846 - accuracy: 0.8333 - val_loss: 0.5736 - val_accuracy: 0.8000
# Epoch 118/200
# 2/2 - 0s - loss: 0.4844 - accuracy: 0.8333 - val_loss: 0.5730 - val_accuracy: 0.8000
# Epoch 119/200
# 2/2 - 0s - loss: 0.4835 - accuracy: 0.8333 - val_loss: 0.5732 - val_accuracy: 0.8000
# Epoch 120/200
# 2/2 - 0s - loss: 0.4836 - accuracy: 0.8333 - val_loss: 0.5727 - val_accuracy: 0.8000
# Epoch 121/200
# 2/2 - 0s - loss: 0.4823 - accuracy: 0.8333 - val_loss: 0.5731 - val_accuracy: 0.8000
# Epoch 122/200
# 2/2 - 0s - loss: 0.4818 - accuracy: 0.8333 - val_loss: 0.5731 - val_accuracy: 0.8000
# Epoch 123/200
# 2/2 - 0s - loss: 0.4813 - accuracy: 0.8333 - val_loss: 0.5735 - val_accuracy: 0.8000
# Epoch 124/200
# 2/2 - 0s - loss: 0.4809 - accuracy: 0.8333 - val_loss: 0.5738 - val_accuracy: 0.8000
# Epoch 125/200
# 2/2 - 0s - loss: 0.4803 - accuracy: 0.8333 - val_loss: 0.5735 - val_accuracy: 0.8000
# Epoch 126/200
# 2/2 - 0s - loss: 0.4798 - accuracy: 0.8333 - val_loss: 0.5728 - val_accuracy: 0.8000
# Epoch 127/200
# 2/2 - 0s - loss: 0.4791 - accuracy: 0.8333 - val_loss: 0.5723 - val_accuracy: 0.8000
# Epoch 128/200
# 2/2 - 0s - loss: 0.4786 - accuracy: 0.8333 - val_loss: 0.5721 - val_accuracy: 0.8000
# Epoch 129/200
# 2/2 - 0s - loss: 0.4782 - accuracy: 0.8333 - val_loss: 0.5715 - val_accuracy: 0.8000
# Epoch 130/200
# 2/2 - 0s - loss: 0.4775 - accuracy: 0.8333 - val_loss: 0.5717 - val_accuracy: 0.8000
# Epoch 131/200
# 2/2 - 0s - loss: 0.4769 - accuracy: 0.8333 - val_loss: 0.5717 - val_accuracy: 0.8000
# Epoch 132/200
# 2/2 - 0s - loss: 0.4765 - accuracy: 0.8333 - val_loss: 0.5711 - val_accuracy: 0.8000
# Epoch 133/200
# 2/2 - 0s - loss: 0.4759 - accuracy: 0.8333 - val_loss: 0.5708 - val_accuracy: 0.8000
# Epoch 134/200
# 2/2 - 0s - loss: 0.4758 - accuracy: 0.8333 - val_loss: 0.5699 - val_accuracy: 0.8000
# Epoch 135/200
# 2/2 - 0s - loss: 0.4749 - accuracy: 0.8333 - val_loss: 0.5702 - val_accuracy: 0.8000
# Epoch 136/200
# 2/2 - 0s - loss: 0.4743 - accuracy: 0.8333 - val_loss: 0.5700 - val_accuracy: 0.8000
# Epoch 137/200
# 2/2 - 0s - loss: 0.4736 - accuracy: 0.8333 - val_loss: 0.5693 - val_accuracy: 0.8000
# Epoch 138/200
# 2/2 - 0s - loss: 0.4730 - accuracy: 0.8333 - val_loss: 0.5689 - val_accuracy: 0.8000
# Epoch 139/200
# 2/2 - 0s - loss: 0.4725 - accuracy: 0.8333 - val_loss: 0.5683 - val_accuracy: 0.8000
# Epoch 140/200
# 2/2 - 0s - loss: 0.4723 - accuracy: 0.8333 - val_loss: 0.5682 - val_accuracy: 0.8000
# Epoch 141/200
# 2/2 - 0s - loss: 0.4717 - accuracy: 0.8333 - val_loss: 0.5678 - val_accuracy: 0.8000
# Epoch 142/200
# 2/2 - 0s - loss: 0.4711 - accuracy: 0.8333 - val_loss: 0.5665 - val_accuracy: 0.8000
# Epoch 143/200
# 2/2 - 0s - loss: 0.4703 - accuracy: 0.8333 - val_loss: 0.5655 - val_accuracy: 0.8000
# Epoch 144/200
# 2/2 - 0s - loss: 0.4697 - accuracy: 0.8333 - val_loss: 0.5650 - val_accuracy: 0.8000
# Epoch 145/200
# 2/2 - 0s - loss: 0.4693 - accuracy: 0.8333 - val_loss: 0.5642 - val_accuracy: 0.8000
# Epoch 146/200
# 2/2 - 0s - loss: 0.4687 - accuracy: 0.8333 - val_loss: 0.5637 - val_accuracy: 0.8000
# Epoch 147/200
# 2/2 - 0s - loss: 0.4681 - accuracy: 0.8333 - val_loss: 0.5633 - val_accuracy: 0.8000
# Epoch 148/200
# 2/2 - 0s - loss: 0.4678 - accuracy: 0.8333 - val_loss: 0.5627 - val_accuracy: 0.8000
# Epoch 149/200
# 2/2 - 0s - loss: 0.4672 - accuracy: 0.8333 - val_loss: 0.5628 - val_accuracy: 0.8000
# Epoch 150/200
# 2/2 - 0s - loss: 0.4666 - accuracy: 0.8333 - val_loss: 0.5628 - val_accuracy: 0.8000
# Epoch 151/200
# 2/2 - 0s - loss: 0.4660 - accuracy: 0.8333 - val_loss: 0.5624 - val_accuracy: 0.8000
# Epoch 152/200
# 2/2 - 0s - loss: 0.4655 - accuracy: 0.8333 - val_loss: 0.5618 - val_accuracy: 0.8000
# Epoch 153/200
# 2/2 - 0s - loss: 0.4650 - accuracy: 0.8333 - val_loss: 0.5614 - val_accuracy: 0.8000
# Epoch 154/200
# 2/2 - 0s - loss: 0.4646 - accuracy: 0.8333 - val_loss: 0.5610 - val_accuracy: 0.8000
# Epoch 155/200
# 2/2 - 0s - loss: 0.4641 - accuracy: 0.8333 - val_loss: 0.5612 - val_accuracy: 0.8000
# Epoch 156/200
# 2/2 - 0s - loss: 0.4636 - accuracy: 0.8333 - val_loss: 0.5606 - val_accuracy: 0.8000
# Epoch 157/200
# 2/2 - 0s - loss: 0.4629 - accuracy: 0.8333 - val_loss: 0.5605 - val_accuracy: 0.8000
# Epoch 158/200
# 2/2 - 0s - loss: 0.4624 - accuracy: 0.8333 - val_loss: 0.5603 - val_accuracy: 0.8000
# Epoch 159/200
# 2/2 - 0s - loss: 0.4619 - accuracy: 0.8333 - val_loss: 0.5604 - val_accuracy: 0.8000
# Epoch 160/200
# 2/2 - 0s - loss: 0.4613 - accuracy: 0.8333 - val_loss: 0.5608 - val_accuracy: 0.8000
# Epoch 161/200
# 2/2 - 0s - loss: 0.4613 - accuracy: 0.8333 - val_loss: 0.5615 - val_accuracy: 0.8000
# Epoch 162/200
# 2/2 - 0s - loss: 0.4607 - accuracy: 0.8333 - val_loss: 0.5617 - val_accuracy: 0.8000
# Epoch 163/200
# 2/2 - 0s - loss: 0.4600 - accuracy: 0.8333 - val_loss: 0.5611 - val_accuracy: 0.8000
# Epoch 164/200
# 2/2 - 0s - loss: 0.4594 - accuracy: 0.8333 - val_loss: 0.5608 - val_accuracy: 0.8000
# Epoch 165/200
# 2/2 - 0s - loss: 0.4588 - accuracy: 0.8333 - val_loss: 0.5600 - val_accuracy: 0.8000
# Epoch 166/200
# 2/2 - 0s - loss: 0.4588 - accuracy: 0.8333 - val_loss: 0.5589 - val_accuracy: 0.8000
# Epoch 167/200
# 2/2 - 0s - loss: 0.4581 - accuracy: 0.8333 - val_loss: 0.5587 - val_accuracy: 0.8000
# Epoch 168/200
# 2/2 - 0s - loss: 0.4574 - accuracy: 0.8333 - val_loss: 0.5580 - val_accuracy: 0.8000
# Epoch 169/200
# 2/2 - 0s - loss: 0.4570 - accuracy: 0.8333 - val_loss: 0.5573 - val_accuracy: 0.8000
# Epoch 170/200
# 2/2 - 0s - loss: 0.4564 - accuracy: 0.8333 - val_loss: 0.5570 - val_accuracy: 0.8000
# Epoch 171/200
# 2/2 - 0s - loss: 0.4563 - accuracy: 0.8333 - val_loss: 0.5565 - val_accuracy: 0.8000
# Epoch 172/200
# 2/2 - 0s - loss: 0.4555 - accuracy: 0.8333 - val_loss: 0.5567 - val_accuracy: 0.8000
# Epoch 173/200
# 2/2 - 0s - loss: 0.4550 - accuracy: 0.8333 - val_loss: 0.5567 - val_accuracy: 0.8000
# Epoch 174/200
# 2/2 - 0s - loss: 0.4545 - accuracy: 0.8333 - val_loss: 0.5564 - val_accuracy: 0.8000
# Epoch 175/200
# 2/2 - 0s - loss: 0.4540 - accuracy: 0.8333 - val_loss: 0.5564 - val_accuracy: 0.8000
# Epoch 176/200
# 2/2 - 0s - loss: 0.4536 - accuracy: 0.8333 - val_loss: 0.5563 - val_accuracy: 0.8000
# Epoch 177/200
# 2/2 - 0s - loss: 0.4531 - accuracy: 0.8333 - val_loss: 0.5561 - val_accuracy: 0.8000
# Epoch 178/200
# 2/2 - 0s - loss: 0.4526 - accuracy: 0.8333 - val_loss: 0.5558 - val_accuracy: 0.8000
# Epoch 179/200
# 2/2 - 0s - loss: 0.4522 - accuracy: 0.8333 - val_loss: 0.5555 - val_accuracy: 0.8000
# Epoch 180/200
# 2/2 - 0s - loss: 0.4517 - accuracy: 0.8333 - val_loss: 0.5552 - val_accuracy: 0.8000
# Epoch 181/200
# 2/2 - 0s - loss: 0.4513 - accuracy: 0.8333 - val_loss: 0.5549 - val_accuracy: 0.8000
# Epoch 182/200
# 2/2 - 0s - loss: 0.4508 - accuracy: 0.8333 - val_loss: 0.5547 - val_accuracy: 0.8000
# Epoch 183/200
# 2/2 - 0s - loss: 0.4506 - accuracy: 0.8333 - val_loss: 0.5542 - val_accuracy: 0.8000
# Epoch 184/200
# 2/2 - 0s - loss: 0.4499 - accuracy: 0.8333 - val_loss: 0.5538 - val_accuracy: 0.8000
# Epoch 185/200
# 2/2 - 0s - loss: 0.4495 - accuracy: 0.8333 - val_loss: 0.5538 - val_accuracy: 0.8000
# Epoch 186/200
# 2/2 - 0s - loss: 0.4492 - accuracy: 0.8333 - val_loss: 0.5541 - val_accuracy: 0.8000
# Epoch 187/200
# 2/2 - 0s - loss: 0.4489 - accuracy: 0.8333 - val_loss: 0.5545 - val_accuracy: 0.8000
# Epoch 188/200
# 2/2 - 0s - loss: 0.4487 - accuracy: 0.8333 - val_loss: 0.5539 - val_accuracy: 0.8000
# Epoch 189/200
# 2/2 - 0s - loss: 0.4480 - accuracy: 0.8333 - val_loss: 0.5542 - val_accuracy: 0.8000
# Epoch 190/200
# 2/2 - 0s - loss: 0.4474 - accuracy: 0.8333 - val_loss: 0.5539 - val_accuracy: 0.8000
# Epoch 191/200
# 2/2 - 0s - loss: 0.4468 - accuracy: 0.8333 - val_loss: 0.5538 - val_accuracy: 0.8000
# Epoch 192/200
# 2/2 - 0s - loss: 0.4464 - accuracy: 0.8333 - val_loss: 0.5535 - val_accuracy: 0.8000
# Epoch 193/200
# 2/2 - 0s - loss: 0.4460 - accuracy: 0.8333 - val_loss: 0.5531 - val_accuracy: 0.8000
# Epoch 194/200
# 2/2 - 0s - loss: 0.4456 - accuracy: 0.8333 - val_loss: 0.5529 - val_accuracy: 0.8000
# Epoch 195/200
# 2/2 - 0s - loss: 0.4453 - accuracy: 0.8333 - val_loss: 0.5526 - val_accuracy: 0.8000
# Epoch 196/200
# 2/2 - 0s - loss: 0.4448 - accuracy: 0.8333 - val_loss: 0.5527 - val_accuracy: 0.8000
# Epoch 197/200
# 2/2 - 0s - loss: 0.4444 - accuracy: 0.8333 - val_loss: 0.5523 - val_accuracy: 0.8000
# Epoch 198/200
# 2/2 - 0s - loss: 0.4440 - accuracy: 0.8333 - val_loss: 0.5521 - val_accuracy: 0.8000
# Epoch 199/200
# 2/2 - 0s - loss: 0.4434 - accuracy: 0.8333 - val_loss: 0.5522 - val_accuracy: 0.8000
# Epoch 200/200
# 2/2 - 0s - loss: 0.4431 - accuracy: 0.8333 - val_loss: 0.5521 - val_accuracy: 0.8000

# %%
model.evaluate(X, y)
# Out:
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4665 - accuracy: 0.8261
# [0.46647995710372925, 0.8260869383811951]
