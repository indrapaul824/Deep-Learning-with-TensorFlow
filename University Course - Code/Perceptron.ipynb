# %% [markdown]
# ### Submitted By:
# # Indrashis Paul
# # 19MIM10046

# %% [markdown]
# # Importing required dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, GridSearchCV
from sklearn.linear_model import Perceptron
import torch
import torch.nn as nn
import torchmetrics

# %% [markdown]
# # Loading data

# %%
data = pd.read_csv('gender.csv')
print(data.shape)
data.head()
# Out:
# (5001, 8)
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male
# 3          1                          1    Male
# 4          0                          0  Female

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   long_hair                  5001 non-null   int64
#  1   forehead_width_cm          5001 non-null   float64
#  2   forehead_height_cm         5001 non-null   float64
#  3   nose_wide                  5001 non-null   int64
#  4   nose_long                  5001 non-null   int64
#  5   lips_thin                  5001 non-null   int64
#  6   distance_nose_to_lip_long  5001 non-null   int64
#  7   gender                     5001 non-null   object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 312.7+ KB

# %% [markdown]
# # Preprocessing
# 1. Label Encoding the Target Column
# 2. Standard scaling the numerical data

# %%
le = LabelEncoder()

data['gender'] = le.fit_transform(data['gender'])
data.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1       1
# 1          1                          0       0
# 2          1                          1       1
# 3          1                          1       1
# 4          0                          0       0

# %%
scaler = MinMaxScaler()

std_col = ['forehead_width_cm','forehead_height_cm']
data[std_col] = scaler.fit_transform(data[std_col])
data.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1           0.097561                0.50          1          0
# 1          0           0.634146                0.15          0          0
# 2          0           0.097561                0.60          1          1
# 3          0           0.731707                0.50          0          1
# 4          1           0.512195                0.40          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1       1
# 1          1                          0       0
# 2          1                          1       1
# 3          1                          1       1
# 4          0                          0       0

# %% [markdown]
# # Building the Perceptron for Classification

# %% [markdown]
# ## Split data

# %%
X = data.drop('gender', axis=1)
y = data['gender']

# %% [markdown]
# ## Using `sklearn.linear_model.Perceptron`

# %% [markdown]
# ### 1. Default Parameters

# %%
# define model
model = Perceptron()

# define model evaluation method
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# summarize result
print(scores)
print(f'Mean Accuracy: {np.mean(scores)} ({np.std(scores)})')
# Out:
# [0.96007984 0.966      0.918      0.942      0.862      0.948
#  0.96       0.958      0.974      0.962      0.96407186 0.926
#  0.762      0.968      0.974      0.946      0.966      0.932
#  0.97       0.916      0.96407186 0.964      0.954      0.96
#  0.96       0.972      0.964      0.946      0.954      0.97      ]
# Mean Accuracy: 0.9460741184298072 (0.041031394921659796)

# %% [markdown]
# ### 2. Custom Parameters

# %%
model = Perceptron(penalty='l1', alpha=0.001, max_iter=2000, tol=1e-3, eta0=1.0021, class_weight='balanced', warm_start=True)

# define model evaluation method
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# summarize result
print(scores)
print(f'Mean Accuracy: {np.mean(scores)} ({np.std(scores)})')
# Out:
# [0.96407186 0.968      0.956      0.958      0.942      0.95
#  0.972      0.892      0.93       0.954      0.96806387 0.898
#  0.952      0.968      0.952      0.964      0.964      0.964
#  0.966      0.97       0.95808383 0.966      0.956      0.962
#  0.888      0.944      0.87       0.952      0.938      0.952     ]
# Mean Accuracy: 0.9479406520292748 (0.02605279354408811)

# %%
model = Perceptron(penalty='l2', alpha=0.00001, max_iter=1000, tol=None, eta0=1.005, class_weight='balanced', warm_start=False)

# define model evaluation method
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# summarize result
print(scores)
print(f'Mean Accuracy: {np.mean(scores)} ({np.std(scores)})')
# Out:
# [0.95608782 0.968      0.974      0.956      0.984      0.946
#  0.962      0.946      0.974      0.928      0.97005988 0.962
#  0.97       0.958      0.962      0.972      0.972      0.91
#  0.948      0.958      0.96207585 0.956      0.962      0.968
#  0.962      0.98       0.94       0.96       0.958      0.964     ]
# Mean Accuracy: 0.9596074517631404 (0.01476504050267687)

# %% [markdown]
# ### 3. Hyperparameter Tuning

# %%
# define model
model = Perceptron()
# define model evaluation method
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# define grid
grid = dict()
grid['eta0'] = [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0]
grid['alpha'] = [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0]
grid['penalty'] = ['l1', 'l2', 'elasticnet', 'None']
grid['tol'] = [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0]
grid['validation_fraction'] = [0.1, 0.15, 0.2, 0.25, 0.3]

# define search
search = GridSearchCV(model, grid, scoring='accuracy', cv=cv, n_jobs=-1)
# perform the search
results = search.fit(X, y)
# summarize
print('Best Mean Accuracy: %.3f' % results.best_score_)
print('Best Config: %s' % results.best_params_)
# summarize all
means = results.cv_results_['mean_test_score']
params = results.cv_results_['params']
for mean, param in zip(means, params):
    print(">%.3f with: %r" % (mean, param))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_79427/3369579704.py in <module>
#      14 search = GridSearchCV(model, grid, scoring='accuracy', cv=cv, n_jobs=-1)
#      15 # perform the search
# ---> 16 results = search.fit(X, y)
#      17 # summarize
#      18 print('Best Mean Accuracy: %.3f' % results.best_score_)
#
# ~/anaconda3/envs/ptDL-39/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/envs/ptDL-39/lib/python3.9/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# ~/anaconda3/envs/ptDL-39/lib/python3.9/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1294     def _run_search(self, evaluate_candidates):
#    1295         """Search all candidates in param_grid"""
# -> 1296         evaluate_candidates(ParameterGrid(self.param_grid))
#    1297
#    1298
#
# ~/anaconda3/envs/ptDL-39/lib/python3.9/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     793                               n_splits, n_candidates, n_candidates * n_splits))
#     794
# --> 795                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     796                                                        X, y,
#     797                                                        train=train, test=test,
#
# ~/anaconda3/envs/ptDL-39/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# ~/anaconda3/envs/ptDL-39/lib/python3.9/site-packages/joblib/parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# ~/anaconda3/envs/ptDL-39/lib/python3.9/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/anaconda3/envs/ptDL-39/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     438                     return self.__get_result()
#     439
# --> 440                 self._condition.wait(timeout)
#     441
#     442                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/anaconda3/envs/ptDL-39/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Using `torch.nn.Sequential`

# %%
# build the model
Perceptron = nn.Sequential(
    nn.Linear(7,1),   # input layer
    nn.Sigmoid()
  )

Perceptron
# Out:
# Sequential(
#   (0): Linear(in_features=7, out_features=1, bias=True)
#   (1): Sigmoid()
# )

# %%
X = X.values
y = y.values
y = y.reshape((y.shape[0], 1))

# %%
X = torch.tensor(X).float()
y = torch.tensor(y).float()

print(X.shape)
print(y.shape)
# Out:
# torch.Size([5001, 7])
# torch.Size([5001, 1])

# %%
# other model features
learningRate = .03

# loss function
lossfun = nn.BCELoss()

# optimizer
optimizer = torch.optim.Adam(Perceptron.parameters(),lr=learningRate)

# %%
# train the model
numepochs = 1000
losses = torch.zeros(numepochs)

for epochi in range(numepochs):

  # forward pass
  yHat = Perceptron(X)

  # compute loss
  loss = lossfun(yHat, y)
  losses[epochi] = loss

  # backprop
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()

# %%
# show the losses

plt.plot(losses.detach(),'o',markerfacecolor='w',linewidth=.1)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
Perceptron.eval()
y_pred = Perceptron(X)

acc = torchmetrics.functional.accuracy(y_pred.int(), y.int())
acc
# Out:
# tensor(0.5001)

# %% [markdown]
# ## Using `tf.keras.layers.Dense`

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, MinMaxScaler
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %%
data = pd.read_csv('gender.csv')
print(data.shape)
data.head()
# Out:
# (5001, 8)
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male
# 3          1                          1    Male
# 4          0                          0  Female

# %%
le = LabelEncoder()

data['gender'] = le.fit_transform(data['gender'])
data
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
#       lips_thin  distance_nose_to_lip_long  gender
# 0             1                          1       1
# 1             1                          0       0
# 2             1                          1       1
# 3             1                          1       1
# 4             0                          0       0
# ...         ...                        ...     ...
# 4996          0                          0       0
# 4997          0                          0       0
# 4998          0                          0       0
# 4999          0                          0       0
# 5000          1                          1       1
#
# [5001 rows x 8 columns]

# %%
sc = MinMaxScaler()

num = ['forehead_width_cm', 'forehead_height_cm']
data[num] = sc.fit_transform(data[num])
data
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1           0.097561                0.50          1          0
# 1             0           0.634146                0.15          0          0
# 2             0           0.097561                0.60          1          1
# 3             0           0.731707                0.50          0          1
# 4             1           0.512195                0.40          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1           0.536585                0.00          0          0
# 4997          1           0.121951                0.15          0          0
# 4998          1           0.365854                0.30          0          0
# 4999          1           0.439024                0.55          0          0
# 5000          1           0.975610                0.15          1          1
#
#       lips_thin  distance_nose_to_lip_long  gender
# 0             1                          1       1
# 1             1                          0       0
# 2             1                          1       1
# 3             1                          1       1
# 4             0                          0       0
# ...         ...                        ...     ...
# 4996          0                          0       0
# 4997          0                          0       0
# 4998          0                          0       0
# 4999          0                          0       0
# 5000          1                          1       1
#
# [5001 rows x 8 columns]

# %%
X = data.iloc[:, :data.shape[1]-1].values
y = data.iloc[:, data.shape[1]-1:].values

# %%
model = Sequential()
model.add(Dense(1, input_shape=(7,), activation='relu'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 8
# =================================================================
# Total params: 8
# Trainable params: 8
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X, y, batch_size=25, epochs=75, verbose=2, validation_split=0.2)
# Out:
# Epoch 1/75
# 160/160 - 0s - loss: 0.0965 - accuracy: 0.9635 - val_loss: 0.1139 - val_accuracy: 0.9690
# Epoch 2/75
# 160/160 - 0s - loss: 0.0962 - accuracy: 0.9645 - val_loss: 0.1134 - val_accuracy: 0.9690
# Epoch 3/75
# 160/160 - 0s - loss: 0.0960 - accuracy: 0.9643 - val_loss: 0.1130 - val_accuracy: 0.9690
# Epoch 4/75
# 160/160 - 0s - loss: 0.0957 - accuracy: 0.9650 - val_loss: 0.1126 - val_accuracy: 0.9680
# Epoch 5/75
# 160/160 - 0s - loss: 0.0954 - accuracy: 0.9655 - val_loss: 0.1122 - val_accuracy: 0.9690
# Epoch 6/75
# 160/160 - 0s - loss: 0.0938 - accuracy: 0.9638 - val_loss: 0.0993 - val_accuracy: 0.9720
# Epoch 7/75
# 160/160 - 0s - loss: 0.0923 - accuracy: 0.9657 - val_loss: 0.0996 - val_accuracy: 0.9720
# Epoch 8/75
# 160/160 - 0s - loss: 0.0922 - accuracy: 0.9655 - val_loss: 0.0998 - val_accuracy: 0.9710
# Epoch 9/75
# 160/160 - 0s - loss: 0.0922 - accuracy: 0.9655 - val_loss: 0.0998 - val_accuracy: 0.9710
# Epoch 10/75
# 160/160 - 0s - loss: 0.0922 - accuracy: 0.9657 - val_loss: 0.0994 - val_accuracy: 0.9720
# Epoch 11/75
# 160/160 - 0s - loss: 0.0922 - accuracy: 0.9655 - val_loss: 0.0996 - val_accuracy: 0.9720
# Epoch 12/75
# 160/160 - 0s - loss: 0.0921 - accuracy: 0.9657 - val_loss: 0.0996 - val_accuracy: 0.9720
# Epoch 13/75
# 160/160 - 0s - loss: 0.0921 - accuracy: 0.9660 - val_loss: 0.0995 - val_accuracy: 0.9720
# Epoch 14/75
# 160/160 - 0s - loss: 0.0921 - accuracy: 0.9657 - val_loss: 0.1016 - val_accuracy: 0.9680
# Epoch 15/75
# 160/160 - 0s - loss: 0.0921 - accuracy: 0.9660 - val_loss: 0.0999 - val_accuracy: 0.9710
# Epoch 16/75
# 160/160 - 0s - loss: 0.0920 - accuracy: 0.9660 - val_loss: 0.0995 - val_accuracy: 0.9720
# Epoch 17/75
# 160/160 - 0s - loss: 0.0924 - accuracy: 0.9655 - val_loss: 0.1011 - val_accuracy: 0.9690
# Epoch 18/75
# 160/160 - 0s - loss: 0.0921 - accuracy: 0.9655 - val_loss: 0.1003 - val_accuracy: 0.9690
# Epoch 19/75
# 160/160 - 0s - loss: 0.0921 - accuracy: 0.9655 - val_loss: 0.1004 - val_accuracy: 0.9690
# Epoch 20/75
# 160/160 - 0s - loss: 0.0924 - accuracy: 0.9653 - val_loss: 0.1120 - val_accuracy: 0.9670
# Epoch 21/75
# 160/160 - 0s - loss: 0.0959 - accuracy: 0.9660 - val_loss: 0.0974 - val_accuracy: 0.9740
# Epoch 22/75
# 160/160 - 0s - loss: 0.0971 - accuracy: 0.9650 - val_loss: 0.0972 - val_accuracy: 0.9730
# Epoch 23/75
# 160/160 - 0s - loss: 0.0970 - accuracy: 0.9653 - val_loss: 0.0972 - val_accuracy: 0.9700
# Epoch 24/75
# 160/160 - 0s - loss: 0.0973 - accuracy: 0.9660 - val_loss: 0.0972 - val_accuracy: 0.9730
# Epoch 25/75
# 160/160 - 0s - loss: 0.0967 - accuracy: 0.9650 - val_loss: 0.0971 - val_accuracy: 0.9730
# Epoch 26/75
# 160/160 - 0s - loss: 0.0972 - accuracy: 0.9650 - val_loss: 0.0876 - val_accuracy: 0.9730
# Epoch 27/75
# 160/160 - 0s - loss: 0.0970 - accuracy: 0.9655 - val_loss: 0.0882 - val_accuracy: 0.9730
# Epoch 28/75
# 160/160 - 0s - loss: 0.0966 - accuracy: 0.9653 - val_loss: 0.0871 - val_accuracy: 0.9740
# Epoch 29/75
# 160/160 - 0s - loss: 0.0964 - accuracy: 0.9665 - val_loss: 0.0977 - val_accuracy: 0.9720
# Epoch 30/75
# 160/160 - 0s - loss: 0.0987 - accuracy: 0.9668 - val_loss: 0.0970 - val_accuracy: 0.9720
# Epoch 31/75
# 160/160 - 0s - loss: 0.0983 - accuracy: 0.9670 - val_loss: 0.0868 - val_accuracy: 0.9720
# Epoch 32/75
# 160/160 - 0s - loss: 0.1011 - accuracy: 0.9640 - val_loss: 0.0890 - val_accuracy: 0.9720
# Epoch 33/75
# 160/160 - 0s - loss: 0.0986 - accuracy: 0.9660 - val_loss: 0.0878 - val_accuracy: 0.9730
# Epoch 34/75
# 160/160 - 0s - loss: 0.0982 - accuracy: 0.9665 - val_loss: 0.0879 - val_accuracy: 0.9710
# Epoch 35/75
# 160/160 - 0s - loss: 0.0980 - accuracy: 0.9665 - val_loss: 0.0966 - val_accuracy: 0.9730
# Epoch 36/75
# 160/160 - 0s - loss: 0.0976 - accuracy: 0.9665 - val_loss: 0.0962 - val_accuracy: 0.9720
# Epoch 37/75
# 160/160 - 0s - loss: 0.0974 - accuracy: 0.9672 - val_loss: 0.0961 - val_accuracy: 0.9740
# Epoch 38/75
# 160/160 - 0s - loss: 0.0972 - accuracy: 0.9670 - val_loss: 0.0963 - val_accuracy: 0.9750
# Epoch 39/75
# 160/160 - 0s - loss: 0.0972 - accuracy: 0.9670 - val_loss: 0.0859 - val_accuracy: 0.9690
# Epoch 40/75
# 160/160 - 0s - loss: 0.0969 - accuracy: 0.9668 - val_loss: 0.0954 - val_accuracy: 0.9740
# Epoch 41/75
# 160/160 - 0s - loss: 0.0969 - accuracy: 0.9663 - val_loss: 0.0857 - val_accuracy: 0.9700
# Epoch 42/75
# 160/160 - 0s - loss: 0.0969 - accuracy: 0.9672 - val_loss: 0.0949 - val_accuracy: 0.9730
# Epoch 43/75
# 160/160 - 0s - loss: 0.0969 - accuracy: 0.9672 - val_loss: 0.0949 - val_accuracy: 0.9740
# Epoch 44/75
# 160/160 - 0s - loss: 0.0967 - accuracy: 0.9675 - val_loss: 0.0949 - val_accuracy: 0.9740
# Epoch 45/75
# 160/160 - 0s - loss: 0.0968 - accuracy: 0.9690 - val_loss: 0.0943 - val_accuracy: 0.9740
# Epoch 46/75
# 160/160 - 0s - loss: 0.0966 - accuracy: 0.9685 - val_loss: 0.0945 - val_accuracy: 0.9720
# Epoch 47/75
# 160/160 - 0s - loss: 0.0966 - accuracy: 0.9682 - val_loss: 0.1090 - val_accuracy: 0.9720
# Epoch 48/75
# 160/160 - 0s - loss: 0.0969 - accuracy: 0.9678 - val_loss: 0.0944 - val_accuracy: 0.9710
# Epoch 49/75
# 160/160 - 0s - loss: 0.0976 - accuracy: 0.9663 - val_loss: 0.0950 - val_accuracy: 0.9700
# Epoch 50/75
# 160/160 - 0s - loss: 0.0964 - accuracy: 0.9672 - val_loss: 0.0941 - val_accuracy: 0.9740
# Epoch 51/75
# 160/160 - 0s - loss: 0.0964 - accuracy: 0.9693 - val_loss: 0.0942 - val_accuracy: 0.9730
# Epoch 52/75
# 160/160 - 0s - loss: 0.0968 - accuracy: 0.9678 - val_loss: 0.0941 - val_accuracy: 0.9760
# Epoch 53/75
# 160/160 - 0s - loss: 0.0966 - accuracy: 0.9682 - val_loss: 0.0936 - val_accuracy: 0.9710
# Epoch 54/75
# 160/160 - 0s - loss: 0.0962 - accuracy: 0.9682 - val_loss: 0.0939 - val_accuracy: 0.9700
# Epoch 55/75
# 160/160 - 0s - loss: 0.0963 - accuracy: 0.9688 - val_loss: 0.0933 - val_accuracy: 0.9730
# Epoch 56/75
# 160/160 - 0s - loss: 0.0961 - accuracy: 0.9680 - val_loss: 0.0935 - val_accuracy: 0.9740
# Epoch 57/75
# 160/160 - 0s - loss: 0.0991 - accuracy: 0.9688 - val_loss: 0.0958 - val_accuracy: 0.9700
# Epoch 58/75
# 160/160 - 0s - loss: 0.0962 - accuracy: 0.9675 - val_loss: 0.0938 - val_accuracy: 0.9700
# Epoch 59/75
# 160/160 - 0s - loss: 0.0961 - accuracy: 0.9678 - val_loss: 0.0947 - val_accuracy: 0.9690
# Epoch 60/75
# 160/160 - 0s - loss: 0.0958 - accuracy: 0.9678 - val_loss: 0.0937 - val_accuracy: 0.9740
# Epoch 61/75
# 160/160 - 0s - loss: 0.0968 - accuracy: 0.9672 - val_loss: 0.1038 - val_accuracy: 0.9720
# Epoch 62/75
# 160/160 - 1s - loss: 0.0963 - accuracy: 0.9665 - val_loss: 0.0933 - val_accuracy: 0.9720
# Epoch 63/75
# 160/160 - 0s - loss: 0.0958 - accuracy: 0.9675 - val_loss: 0.0933 - val_accuracy: 0.9750
# Epoch 64/75
# 160/160 - 0s - loss: 0.0958 - accuracy: 0.9678 - val_loss: 0.0933 - val_accuracy: 0.9730
# Epoch 65/75
# 160/160 - 0s - loss: 0.0956 - accuracy: 0.9682 - val_loss: 0.0937 - val_accuracy: 0.9710
# Epoch 66/75
# 160/160 - 0s - loss: 0.0958 - accuracy: 0.9672 - val_loss: 0.1066 - val_accuracy: 0.9760
# Epoch 67/75
# 160/160 - 0s - loss: 0.0972 - accuracy: 0.9668 - val_loss: 0.0934 - val_accuracy: 0.9760
# Epoch 68/75
# 160/160 - 0s - loss: 0.0958 - accuracy: 0.9688 - val_loss: 0.0925 - val_accuracy: 0.9740
# Epoch 69/75
# 160/160 - 0s - loss: 0.0955 - accuracy: 0.9685 - val_loss: 0.0927 - val_accuracy: 0.9730
# Epoch 70/75
# 160/160 - 0s - loss: 0.0955 - accuracy: 0.9675 - val_loss: 0.0935 - val_accuracy: 0.9720
# Epoch 71/75
# 160/160 - 0s - loss: 0.0957 - accuracy: 0.9685 - val_loss: 0.0927 - val_accuracy: 0.9750
# Epoch 72/75
# 160/160 - 0s - loss: 0.0956 - accuracy: 0.9680 - val_loss: 0.1036 - val_accuracy: 0.9700
# Epoch 73/75
# 160/160 - 0s - loss: 0.0954 - accuracy: 0.9672 - val_loss: 0.0930 - val_accuracy: 0.9750
# Epoch 74/75
# 160/160 - 0s - loss: 0.0955 - accuracy: 0.9678 - val_loss: 0.0928 - val_accuracy: 0.9750
# Epoch 75/75
# 160/160 - 0s - loss: 0.0955 - accuracy: 0.9675 - val_loss: 0.0939 - val_accuracy: 0.9780

# %%
model.evaluate(X, y)
# Out:
# 157/157 [==============================] - 1s 7ms/step - loss: 0.0958 - accuracy: 0.9696
# [0.09584224224090576, 0.9696061015129089]
