# %% [markdown]
# # Assignment 8
#
# ### Submitted By:
# Indrashis Paul, 19MIM10046
#
# ### Consider the following data set of Liquor consumption drinks.csv. Write a program in python

# %%
import pandas as pd

# %% [markdown]
# ### 1. To read the file.

# %%
data = pd.read_csv('./data/drinks.csv')
data.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %% [markdown]
# ### 2. To convert country name to capital letters.

# %%
data['country'] = data['country'].str.upper()

# %%
data
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    AFGHANISTAN              0                0              0
# 1        ALBANIA             89              132             54
# 2        ALGERIA             25                0             14
# 3        ANDORRA            245              138            312
# 4         ANGOLA            217               57             45
# ..           ...            ...              ...            ...
# 188    VENEZUELA            333              100              3
# 189      VIETNAM            111                2              1
# 190        YEMEN              6                0              0
# 191       ZAMBIA             32               19              4
# 192     ZIMBABWE             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %% [markdown]
# ### 3. Total liquor requirement of each type in each Continent

# %%
data.groupby('continent').sum()
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa                  3258              866            862
# Asia                    1630             2677            399
# Europe                  8720             5965           6400
# North America           3345             3812            564
# Oceania                 1435              935            570
# South America           2101             1377            749
#
#                total_litres_of_pure_alcohol
# continent
# Africa                                159.4
# Asia                                   95.5
# Europe                                387.8
# North America                         137.9
# Oceania                                54.1
# South America                          75.7

# %% [markdown]
# ### 4. Country wise type of liquor which is consumed in maximum quantity

# %%
data_country = data.groupby('country').sum()

data_country['max_liquor_type'] = data_country.idxmax(axis=1)

data_country['max_liquor'] = data_country[['beer_servings', 'spirit_servings', 'wine_servings', 'total_litres_of_pure_alcohol']].max(axis=1)

data_country[['max_liquor_type', 'max_liquor']]
# Out:
#              max_liquor_type  max_liquor
# country
# AFGHANISTAN    beer_servings         0.0
# ALBANIA      spirit_servings       132.0
# ALGERIA        beer_servings        25.0
# ANDORRA        wine_servings       312.0
# ANGOLA         beer_servings       217.0
# ...                      ...         ...
# VENEZUELA      beer_servings       333.0
# VIETNAM        beer_servings       111.0
# YEMEN          beer_servings         6.0
# ZAMBIA         beer_servings        32.0
# ZIMBABWE       beer_servings        64.0
#
# [193 rows x 2 columns]

# %% [markdown]
# ### 5. Country wise total liquor consumption of each type

# %%
data_country.iloc[:,:-2]
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# AFGHANISTAN              0                0              0
# ALBANIA                 89              132             54
# ALGERIA                 25                0             14
# ANDORRA                245              138            312
# ANGOLA                 217               57             45
# ...                    ...              ...            ...
# VENEZUELA              333              100              3
# VIETNAM                111                2              1
# YEMEN                    6                0              0
# ZAMBIA                  32               19              4
# ZIMBABWE                64               18              4
#
#              total_litres_of_pure_alcohol
# country
# AFGHANISTAN                           0.0
# ALBANIA                               4.9
# ALGERIA                               0.7
# ANDORRA                              12.4
# ...
