# %% [markdown]
# # OR Gate Output prediction using predefined Network from Paper

# %% [markdown]
# ## Imports

# %%
import numpy as np

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## Creating the data

# %%
X = np.array([[0, 0],
              [0, 1], 
              [1, 0], 
              [1, 1]], "float32")
y = np.array([[0], 
              [1], 
              [1], 
              [1]], "float32")

# %% [markdown]
# ## Building, training and evaluating the TF NN model

# %% [markdown]
# ### Creating a custom Callback to stop when accuracy reaches 100

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        thres = 1.0
        if(logs.get('accuracy') >= thres): # Experiment with changing this value
            print(f"\nReached {thres*100}% accuracy on epoch = {epoch+1}!")
            self.model.stop_training = True

# %% [markdown]
# ### MLP Model with 2 Hidden Layers epochs: 200

# %%
callback = myCallback()
model = Sequential([
    Dense(32, input_dim=2, activation='relu'),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(loss='mean_squared_error', 
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(X, y, epochs=200, callbacks=[callback], verbose=2)
# Out:
# Epoch 1/200
# 1/1 - 4s - loss: 0.2730 - accuracy: 0.2500
# Epoch 2/200
# 1/1 - 0s - loss: 0.2703 - accuracy: 0.0000e+00
# Epoch 3/200
# 1/1 - 0s - loss: 0.2677 - accuracy: 0.0000e+00
# Epoch 4/200
# 1/1 - 0s - loss: 0.2654 - accuracy: 0.0000e+00
# Epoch 5/200
# 1/1 - 0s - loss: 0.2632 - accuracy: 0.0000e+00
# Epoch 6/200
# 1/1 - 0s - loss: 0.2610 - accuracy: 0.0000e+00
# Epoch 7/200
# 1/1 - 0s - loss: 0.2589 - accuracy: 0.0000e+00
# Epoch 8/200
# 1/1 - 0s - loss: 0.2569 - accuracy: 0.5000
# Epoch 9/200
# 1/1 - 0s - loss: 0.2547 - accuracy: 0.5000
# Epoch 10/200
# 1/1 - 0s - loss: 0.2528 - accuracy: 0.5000
# Epoch 11/200
# 1/1 - 0s - loss: 0.2512 - accuracy: 0.5000
# Epoch 12/200
# 1/1 - 0s - loss: 0.2499 - accuracy: 0.5000
# Epoch 13/200
# 1/1 - 0s - loss: 0.2486 - accuracy: 0.5000
# Epoch 14/200
# 1/1 - 0s - loss: 0.2474 - accuracy: 0.5000
# Epoch 15/200
# 1/1 - 0s - loss: 0.2462 - accuracy: 0.5000
# Epoch 16/200
# 1/1 - 0s - loss: 0.2452 - accuracy: 0.5000
# Epoch 17/200
# 1/1 - 0s - loss: 0.2443 - accuracy: 0.5000
# Epoch 18/200
# 1/1 - 0s - loss: 0.2433 - accuracy: 0.5000
# Epoch 19/200
# 1/1 - 0s - loss: 0.2423 - accuracy: 0.7500
# Epoch 20/200
# 1/1 - 0s - loss: 0.2412 - accuracy: 0.7500
# Epoch 21/200
# 1/1 - 0s - loss: 0.2401 - accuracy: 0.7500
# Epoch 22/200
# 1/1 - 0s - loss: 0.2394 - accuracy: 0.7500
# Epoch 23/200
# 1/1 - 0s - loss: 0.2386 - accuracy: 0.7500
# Epoch 24/200
# 1/1 - 0s - loss: 0.2378 - accuracy: 0.7500
# Epoch 25/200
# 1/1 - 0s - loss: 0.2370 - accuracy: 0.7500
# Epoch 26/200
# 1/1 - 0s - loss: 0.2362 - accuracy: 0.7500
# Epoch 27/200
# 1/1 - 0s - loss: 0.2353 - accuracy: 0.7500
# Epoch 28/200
# 1/1 - 0s - loss: 0.2346 - accuracy: 0.7500
# Epoch 29/200
# 1/1 - 0s - loss: 0.2338 - accuracy: 0.7500
# Epoch 30/200
# 1/1 - 0s - loss: 0.2331 - accuracy: 0.7500
# Epoch 31/200
# 1/1 - 0s - loss: 0.2324 - accuracy: 0.7500
# Epoch 32/200
# 1/1 - 0s - loss: 0.2316 - accuracy: 0.7500
# Epoch 33/200
# 1/1 - 0s - loss: 0.2308 - accuracy: 0.7500
# Epoch 34/200
# 1/1 - 0s - loss: 0.2301 - accuracy: 0.7500
# Epoch 35/200
# 1/1 - 0s - loss: 0.2293 - accuracy: 0.7500
# Epoch 36/200
# 1/1 - 0s - loss: 0.2286 - accuracy: 0.7500
# Epoch 37/200
# 1/1 - 0s - loss: 0.2278 - accuracy: 0.7500
# Epoch 38/200
# 1/1 - 0s - loss: 0.2269 - accuracy: 0.7500
# Epoch 39/200
# 1/1 - 0s - loss: 0.2261 - accuracy: 0.7500
# Epoch 40/200
# 1/1 - 0s - loss: 0.2252 - accuracy: 0.7500
# Epoch 41/200
# 1/1 - 0s - loss: 0.2244 - accuracy: 0.7500
# Epoch 42/200
# 1/1 - 0s - loss: 0.2235 - accuracy: 0.7500
# Epoch 43/200
# 1/1 - 0s - loss: 0.2227 - accuracy: 0.7500
# Epoch 44/200
# 1/1 - 0s - loss: 0.2218 - accuracy: 0.7500
# Epoch 45/200
# 1/1 - 0s - loss: 0.2209 - accuracy: 0.7500
# Epoch 46/200
# 1/1 - 0s - loss: 0.2200 - accuracy: 0.7500
# Epoch 47/200
# 1/1 - 0s - loss: 0.2191 - accuracy: 0.7500
# Epoch 48/200
# 1/1 - 0s - loss: 0.2182 - accuracy: 0.7500
# Epoch 49/200
# 1/1 - 0s - loss: 0.2172 - accuracy: 0.7500
# Epoch 50/200
# 1/1 - 0s - loss: 0.2163 - accuracy: 0.7500
# Epoch 51/200
# 1/1 - 0s - loss: 0.2153 - accuracy: 0.7500
# Epoch 52/200
# 1/1 - 0s - loss: 0.2143 - accuracy: 0.7500
# Epoch 53/200
# 1/1 - 0s - loss: 0.2133 - accuracy: 0.7500
# Epoch 54/200
# 1/1 - 0s - loss: 0.2122 - accuracy: 0.7500
# Epoch 55/200
# 1/1 - 0s - loss: 0.2112 - accuracy: 0.7500
# Epoch 56/200
# 1/1 - 0s - loss: 0.2102 - accuracy: 0.7500
# Epoch 57/200
# 1/1 - 0s - loss: 0.2092 - accuracy: 0.7500
# Epoch 58/200
# 1/1 - 0s - loss: 0.2081 - accuracy: 0.7500
# Epoch 59/200
# 1/1 - 0s - loss: 0.2071 - accuracy: 0.7500
# Epoch 60/200
# 1/1 - 0s - loss: 0.2060 - accuracy: 0.7500
# Epoch 61/200
# 1/1 - 0s - loss: 0.2049 - accuracy: 0.7500
# Epoch 62/200
# 1/1 - 0s - loss: 0.2038 - accuracy: 0.7500
# Epoch 63/200
# 1/1 - 0s - loss: 0.2027 - accuracy: 0.7500
# Epoch 64/200
# 1/1 - 0s - loss: 0.2015 - accuracy: 0.7500
# Epoch 65/200
# 1/1 - 0s - loss: 0.2003 - accuracy: 0.7500
# Epoch 66/200
# 1/1 - 0s - loss: 0.1991 - accuracy: 0.7500
# Epoch 67/200
# 1/1 - 0s - loss: 0.1978 - accuracy: 0.7500
# Epoch 68/200
# 1/1 - 0s - loss: 0.1965 - accuracy: 0.7500
# Epoch 69/200
# 1/1 - 0s - loss: 0.1951 - accuracy: 0.7500
# Epoch 70/200
# 1/1 - 0s - loss: 0.1938 - accuracy: 0.7500
# Epoch 71/200
# 1/1 - 0s - loss: 0.1924 - accuracy: 0.7500
# Epoch 72/200
# 1/1 - 0s - loss: 0.1910 - accuracy: 0.7500
# Epoch 73/200
# 1/1 - 0s - loss: 0.1896 - accuracy: 0.7500
# Epoch 74/200
# 1/1 - 0s - loss: 0.1881 - accuracy: 0.7500
# Epoch 75/200
# 1/1 - 0s - loss: 0.1867 - accuracy: 0.7500
# Epoch 76/200
# 1/1 - 0s - loss: 0.1851 - accuracy: 0.7500
# Epoch 77/200
# 1/1 - 0s - loss: 0.1836 - accuracy: 0.7500
# Epoch 78/200
# 1/1 - 0s - loss: 0.1819 - accuracy: 0.7500
# Epoch 79/200
# 1/1 - 0s - loss: 0.1803 - accuracy: 0.7500
# Epoch 80/200
# 1/1 - 0s - loss: 0.1786 - accuracy: 0.7500
# Epoch 81/200
# 1/1 - 0s - loss: 0.1770 - accuracy: 0.7500
# Epoch 82/200
# 1/1 - 0s - loss: 0.1752 - accuracy: 0.7500
# Epoch 83/200
# 1/1 - 0s - loss: 0.1735 - accuracy: 0.7500
# Epoch 84/200
# 1/1 - 0s - loss: 0.1718 - accuracy: 0.7500
# Epoch 85/200
# 1/1 - 0s - loss: 0.1701 - accuracy: 0.7500
# Epoch 86/200
# 1/1 - 0s - loss: 0.1684 - accuracy: 0.7500
# Epoch 87/200
# 1/1 - 0s - loss: 0.1666 - accuracy: 0.7500
# Epoch 88/200
# 1/1 - 0s - loss: 0.1648 - accuracy: 0.7500
# Epoch 89/200
# 1/1 - 0s - loss: 0.1630 - accuracy: 0.7500
# Epoch 90/200
# 1/1 - 0s - loss: 0.1612 - accuracy: 0.7500
# Epoch 91/200
# 1/1 - 0s - loss: 0.1594 - accuracy: 0.7500
# Epoch 92/200
# 1/1 - 0s - loss: 0.1577 - accuracy: 0.7500
# Epoch 93/200
# 1/1 - 0s - loss: 0.1560 - accuracy: 0.7500
# Epoch 94/200
# 1/1 - 0s - loss: 0.1542 - accuracy: 0.7500
# Epoch 95/200
# 1/1 - 0s - loss: 0.1524 - accuracy: 0.7500
# Epoch 96/200
# 1/1 - 0s - loss: 0.1506 - accuracy: 0.7500
# Epoch 97/200
# 1/1 - 0s - loss: 0.1489 - accuracy: 0.7500
# Epoch 98/200
# 1/1 - 0s - loss: 0.1472 - accuracy: 0.7500
# Epoch 99/200
# 1/1 - 0s - loss: 0.1455 - accuracy: 0.7500
# Epoch 100/200
# 1/1 - 0s - loss: 0.1437 - accuracy: 0.7500
# Epoch 101/200
# 1/1 - 0s - loss: 0.1420 - accuracy: 0.7500
# Epoch 102/200
# 1/1 - 0s - loss: 0.1403 - accuracy: 0.7500
# Epoch 103/200
# 1/1 - 0s - loss: 0.1385 - accuracy: 0.7500
# Epoch 104/200
# 1/1 - 0s - loss: 0.1369 - accuracy: 0.7500
# Epoch 105/200
# 1/1 - 0s - loss: 0.1352 - accuracy: 0.7500
# Epoch 106/200
# 1/1 - 0s - loss: 0.1335 - accuracy: 0.7500
# Epoch 107/200
# 1/1 - 0s - loss: 0.1319 - accuracy: 0.7500
# Epoch 108/200
# 1/1 - 0s - loss: 0.1302 - accuracy: 0.7500
# Epoch 109/200
# 1/1 - 0s - loss: 0.1287 - accuracy: 0.7500
# Epoch 110/200
# 1/1 - 0s - loss: 0.1271 - accuracy: 0.7500
# Epoch 111/200
# 1/1 - 0s - loss: 0.1255 - accuracy: 0.7500
# Epoch 112/200
# 1/1 - 0s - loss: 0.1238 - accuracy: 0.7500
# Epoch 113/200
# 1/1 - 0s - loss: 0.1223 - accuracy: 0.7500
# Epoch 114/200
# 1/1 - 0s - loss: 0.1208 - accuracy: 0.7500
# Epoch 115/200
# 1/1 - 0s - loss: 0.1192 - accuracy: 0.7500
# Epoch 116/200
# 1/1 - 0s - loss: 0.1178 - accuracy: 0.7500
# Epoch 117/200
# 1/1 - 0s - loss: 0.1163 - accuracy: 0.7500
# Epoch 118/200
# 1/1 - 0s - loss: 0.1147 - accuracy: 0.7500
# Epoch 119/200
# 1/1 - 0s - loss: 0.1133 - accuracy: 0.7500
# Epoch 120/200
# 1/1 - 0s - loss: 0.1118 - accuracy: 0.7500
# Epoch 121/200
# 1/1 - 0s - loss: 0.1103 - accuracy: 0.7500
# Epoch 122/200
# 1/1 - 0s - loss: 0.1089 - accuracy: 1.0000
#
# Reached 100.0% accuracy on epoch = 122!

# %%
print(model.predict(X).round())
# Out:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]

# %% [markdown]
# ## Building provided model

# %%
def threshold(x):
    if x>0:
        return 1
    elif x == 0:
        return 0
    return -1

def trained_nn(x, y):
    w3 = [0.4, -0.7]
    w4 = [0.6, -0.5]
    b3 = -0.3
    b4 = 0.4
    w5 = [2.0, 1.0]
    b5 = 0.0
    yhat = []
    
    for xi in x:
        yhat.append(threshold(xi@w3+b3 + xi@b4+b4 + b5))
    
    return yhat

def accuracy(y, yhat):
    if len(y) == len(yhat):
        for i in range(len(y)):
